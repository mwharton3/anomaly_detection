# %%
from visual import *
from data import *
from model import *
import numpy as np
from keras.models import load_model
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # Input data
# This model was trained on 4026 images taken from the inside of a car. The only labels provided indicated whether road imperfections were present or not, making this method weakly supervised. A test set of 710 images were randomly set aside.
#
# ### Data source:
#
# [1] S. Nienaber, M.J. Booysen, R.S. Kroon, “Detecting potholes using simple image processing techniques and real-world footage”, SATC, July 2015, Pretoria, South Africa.
#
# [2] S. Nienaber, R.S. Kroon, M.J. Booysen , “A Comparison of Low-Cost Monocular Vision Techniques for Pothole Distance Estimation”, IEEE CIVTS, December 2015, Cape Town, South Africa.

# %%
# Generate test images (not used to train)
x_test, y_test = generateTestImages()

# %% [markdown]
# # Model
# The model classifies the 710 test images with 97% accuracy.

# %%
# Load the model
model = load_model('model.h5')

# %% [markdown]
# # Results
# Without specifically labeling localized regions, the model is still able to determine areas within each image responsible for the classification.
#
#
# This technique could be used for a wide variety of applications. One particular example would be narrowly defined manufacturing inspection processes that require QA/QC staff in the loop.

# %%
# Show some examples
for i in [59, 39, 34, 30, 22, 10, 13, 19]:
    showAnomalies(model, x_test, y_test, i)
